# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import geopandas as gpd
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster

# %%
location_csv = pd.read_csv('C://Users/anwar/Downloads/FISH_AQUATIC_INVASIVE_SPCS_SP/FSHQTCNVSV.csv')

# %%
f, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 6))
sns.heatmap(location_csv.isna(),cmap='cubehelix',yticklabels=False,cbar=False,ax=ax[0])
# Out:
# <AxesSubplot:>
